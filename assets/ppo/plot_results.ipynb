# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import glob

# %%
for filename in glob.glob('results/*'):
    result = np.load(filename)
    filename = filename[len('results/'):-len('.npy')]
    seed, pi_lr, v_lr, gamma, lam = filename.split('-')
    sns.lineplot(x=range(len(result)), y=result, alpha=0.4)
plt.savefig('swingup.png')
